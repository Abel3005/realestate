# %% [markdown]
# # 청년주택
# 청년을 위한 주거지원

# %% [markdown]
# 비트맵(choropleth)으로 청년 주택 수 출력

# %%
#주택 수 출력
all_apart_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88749b6f5d1106b1aa3080b5b9d42f11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88749b6f5d1106b1aa3080b5b9d42f11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88749b6f5d1106b1aa3080b5b9d42f11 = L.map(
#                 &quot;map_88749b6f5d1106b1aa3080b5b9d42f11&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99adcd77d7a0d2e96f49ea6634443f91 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_99adcd77d7a0d2e96f49ea6634443f91.addTo(map_88749b6f5d1106b1aa3080b5b9d42f11);
#
#
#             var choropleth_6fc852ea87a46a44073e15511208b85d = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_4aea1e6148e31e979d69b169763d9477_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4aea1e6148e31e979d69b169763d9477_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4aea1e6148e31e979d69b169763d9477 = L.geoJson(null, {
#                 onEachFeature: geo_json_4aea1e6148e31e979d69b169763d9477_onEachFeature,
#
#                 style: geo_json_4aea1e6148e31e979d69b169763d9477_styler,
#         });
#
#         function geo_json_4aea1e6148e31e979d69b169763d9477_add (data) {
#             geo_json_4aea1e6148e31e979d69b169763d9477
#                 .addData(data);
#         }
#             geo_json_4aea1e6148e31e979d69b169763d9477_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.4974

# %% [markdown]
# ### 주제
# 청년주택의 가격이 적정하게 형성 되어 있는가 ?
# <br><br>[서울시 청년역세권주택, 주변 시세보다 임대료 오히려 비싸](https://www.asiatime.co.kr/article/20221014500172)<br>
# [4차까지 모집했지만… 청년 외면 받는 행복주택](https://www.kukinews.com/newsView/kuk202206080212)<br>
# <br>등 다양한 기사들 존재

# %% [markdown]
#  - 행복주택과 청년 매입임대주택 및 역세권 청년 주택, 기숙사형 청년주택, 전세임대주택
# <br>![1.PNG](1.PNG)<br>
# <br>서울시 전월세 실거래가 데이터 추출![2.PNG](2.PNG)<br>
# <br>청년안심주택 데이터 크롤링![3.PNG](3.PNG)<br>
# <br>행복주택/매입임대 주택목록 데이터 추출![4.PNG](4.PNG)

# %% [markdown]
# ## 데이터 추출

# %% [markdown]
# ### 전처리과정
# ----------

# %% [markdown]
# - ![6.PNG](6.PNG)<br>
# ![5.PNG](5.PNG)<br>
# --------------------------
# 전월세 전환율에 대한 필요성 인지
# ![7.PNG](7.PNG)<br>
# depositMoney + (rentalMoney * 12) / 0.052

# %% [markdown]
# kindHouse를 보면 주택의 종류가 아파트, 연립, 다세대, 다가구, 오피스텔 등으로 이루어져 있는데<br>
# 우리는 아파트와 나머지를 기준으로 정리를 했으며, 행복주택과 매입임대에도 여러 종류가 있지만, 구성비율을 보면 압도적인 차이들이 있어서
# <br>우리는 아파트와 행복주택, 안심주택 그리고 비아파트와 매입임대를 비교하고자한다

# %% [markdown]
# ![1.P](1_1.jpg)<br>
# ![1.P](1_2.jpg)<br>

# %% [markdown]
# ## 자치구 별, 공급유형 별 평균 가격 비교
#
# - 행복주택과 아파트
# - 공공안심과 아파트
# - 민간안심과 아파트
# - 매입임대와 비아파트 별 비교
# <br><br>평균가를 육안으로 비교 했을때는 민간안심과 행복주택의 평균가격이 높게 잡혀 있음을 보여줌

# %% [markdown]
# ![](1_3.jpg)
# ![](1_4.jpg)
# ![](1_5.jpg)
# ![](1_6.jpg)

# %% [markdown]
# 각 유형별 위에 제시된 비율에 해당 되는지를 체크 데이터프레임으로 보여줌ㅡ,

# %% [markdown]
# 우리는 체크했던 것을 이용해서 행복주택과 안심주택 매입임대에 있는 각 주택에 가격을 비교해 해당되는 지역을 마커를 통해 표시

# %% [markdown]
# ![](2_1.png)
# ![](2_2.png)
# ![](2_3.png)
# ![](2_4.png)

# %% [markdown]
# ![](2_1.jpg)
# ![](2_1.jpg)
# ![](2_1.jpg)

# %%
pd.read_sql("select * from finalResult2",con=con)
# Out:
# /tmp/ipykernel_32188/209966900.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from finalResult2",con=con)
#    종류  해당(%)
# 0  매입  85.50
# 1  행복  27.47
# 2  공공  95.92
# 3  민간  18.37

# %% [markdown]
# # 결론
#
# 1. **청년주택 가격 적절성 평가**: 수집된 데이터와 시각화 결과를 종합하여 청년주택의 가격이 현재 시장 상황과 청년들의 경제적 여건에 부합하는지를 평가합니다.
# 2. **정책적 측면 고려**: 청년주택의 가격이 정부의 정책 목표와 부합하는지를 검토합니다. 정부의 목표는 청년들의 주거 안정성을 증진하고 주거 부담을 완화하는 것입니다.택의 가격이 다른 주거 옵션과 비교하여 경쟁력을 평가합니다. 이를 통해 청년들이 선택할 수 있는 다양한 주거 옵션 중에서 어떤 선택이 가장 적절한지를 판단합니다.
# 3. **수요 및 공급 상태 고려**: 청년들의 주거 수요와 현재 청년주택의 공급 상태를 고려하여 가격 적정성을 평가합니다. 이를 통해 필요에 따라 추가적인 주택 공급이나 정책 개선이 필요한지를 파악합니다.
# 4. **사회적 측면 고려**: 청년들의 주거 문제가 사회적인 안정성과 연관되어 있는지를 고려합니다. 청년들이 안정적인 주거 환경에서 성공적으로 사회에 참여할 수 있는지를 확인합니다.
#
# <br><br>이런것들을 대충 얘기하고 끝냄

# %%
# geocoder 2.0 API로 위도, 경도 데이터 찾기
import requests
from tqdm import tqdm
import pandas as pd
import pymysql

#DB 접속 정보
with open("./db.config",'r') as f:
    db_data = f.read()
db_data = eval(db_data)

#DB 접속
_host = db_data['DB_HOST']
_user = db_data['DB_USER']
_password = db_data['DB_PASSWORD']
_name = db_data['DB_NAME']

con = pymysql.connect(host=f'{_host}', user=f'{_user}', password=f'{_password}', db=f'{_name}', charset='utf8')
cur = con.cursor()

tmp = ''
data = []
failed = []

lh_df = pd.read_sql_query('select * from allLh', con=con)
ansim_df = pd.read_sql_query('select * from ansim', con=con)
# Out:
# /tmp/ipykernel_32188/2656042519.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   lh_df = pd.read_sql_query('select * from allLh', con=con)
# /tmp/ipykernel_32188/2656042519.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ansim_df = pd.read_sql_query('select * from ansim', con=con)

# %%
for idx, row in tqdm(lh_df.iterrows()):
    apiurl = "https://api.vworld.kr/req/address?"
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": row['adresWay'],
        "format": "json",
        "type": "road",
        "key": "DC6503B3-A493-3EC3-AC04-D36A0E1594D4"
    }
    response = requests.get(apiurl, params=params)
    if response.status_code == 200:
        tmp = response.json()
        try:
            data.append(tmp['response']['result']['point'])
        except Exception as e:
            params["type"] = "parcel"
            response = requests.get(apiurl, params=params)
            if response.status_code == 200:
                tmp = response.json()
                try:
                    data.append(tmp['response']['result']['point'])
                except Exception as e:
                    failed.append(idx)

for idx, row in tqdm(ansim_df.iterrows()):
    apiurl = "https://api.vworld.kr/req/address?"
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": row['adresWay'],
        "format": "json",
        "type": "road",
        "key": "DC6503B3-A493-3EC3-AC04-D36A0E1594D4"
    }
    response = requests.get(apiurl, params=params)
    if response.status_code == 200:
        tmp = response.json()
        try:
            data.append(tmp['response']['result']['point'])
        except Exception as e:
            params["type"] = "parcel"
            response = requests.get(apiurl, params=params)
            if response.status_code == 200:
                tmp = response.json()
                try:
                    data.append(tmp['response']['result']['point'])
                except Exception as e:
                    failed.append(idx)
                    
# 위도 경도 데이터 저장
for i in range(len(lh_df)):
    ansim_df.loc[i, 'x'] = data[i]['x']
    ansim_df.loc[i, 'y'] = data[i]['y']

ansim_df.loc[14,'x']='126.8982447'
ansim_df.loc[14,'y']='37.5251247'
ansim_df.loc[41,'x']='126.9167221'
ansim_df.loc[41,'y']='37.5507977'
ansim_df.loc[27,'x']='126.837949'
ansim_df.loc[27,'y']='37.5406894'
# Out:
# /tmp/ipykernel_31146/322590594.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   lh_df = pd.read_sql_query('select * from allLh', con=con)
# /tmp/ipykernel_31146/322590594.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ansim_df = pd.read_sql_query('select * from ansim', con=con)
# 15it [00:02,  5.89it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 45
#      44 try:
# ---> 45     data.append(tmp['response']['result']['point'])
#      46 except Exception as e:
#
# KeyError: 'result'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 48
#      46 except Exception as e:
#      47     params["type"] = "parcel"
# ---> 48     response = requests.get(apiurl, params=params)
#      49     if response.status_code == 200:
#      50         tmp = response.json()
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1097 # Force connect early to allow us to validate the connection.
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1102 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:653, in HTTPSConnection.connect(self)
#     650 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#     673 # Forwarding proxies can never have a verified target since
#     674 # the proxy is the one doing the verification. Should instead
#     675 # use a CONNECT tunnel in order to verify the target.
#     676 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     803     if is_ipaddress(normalized):
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#     820     if assert_fingerprint:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/util/ssl_.py:440, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     438 if ca_certs or ca_cert_dir or ca_cert_data:
#     439     try:
# --> 440         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     441     except OSError as e:
#     442         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
# CSV 파일 저장
lh_df.to_csv('lh_df.csv', index=False)
ansim_df.to_csv('ansim_df.csv', index=False)

# %% [markdown]
# ### 청년 주택 정보 제공

# %%
where_lh = pd.read_csv("./data/lh_df.csv")
where_ansim = pd.read_csv("./data/ansim_df.csv")
#where_lh = lh_df.copy()``
#where_ansim = ansim_df.copy()

# %%
import folium
where_hang = where_lh[where_lh['kindRental'] != '매입임대']
where_all = pd.concat([where_hang,where_ansim])
popmap = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="cartodb positron")
target =  where_all[['x', 'y', 'kindRental','adresWay','adresGu','kindHouse','totArea','scaleTot']].copy()
target['color'] =target.kindRental.apply(lambda x : 'red' if x =="매입임대" else ('blue' if x == "행복주택"  else 'orange')   )
popmap = folium.Map(location=[37.5502, 126.982], zoom_start=11)
for idx, row in target.iterrows():
    folium.Marker([row.y, row.x],
                  popup=f"""<div style="white-space: nowrap;">주소: {row.adresWay}<br>주택 종류: {row.kindHouse}<br>면적: {row.totArea}<br>세대수: {row.scaleTot}</div>""",              
                  icon=folium.Icon(color=row.color, icon='star')
                 ).add_to(popmap)

# %%
#지도 출력
popmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_244f2bb5e33b9838e372940e5b6e3d45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_244f2bb5e33b9838e372940e5b6e3d45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_244f2bb5e33b9838e372940e5b6e3d45 = L.map(
#                 &quot;map_244f2bb5e33b9838e372940e5b6e3d45&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a066d45a3d8a82835ed4f45639259d4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a066d45a3d8a82835ed4f45639259d4b.addTo(map_244f2bb5e33b9838e372940e5b6e3d45);
#
#
#             var marker_5b3e07ccfe59cd3c9af5551d61fdc2f1 = L.marker(
#                 [37.572237074, 126.964496478],
#                 {}
#             ).addTo(map_244f2bb5e33b9838e372940e5b6e3d45);
#
#
#             var icon_0e4a05351bcef1c0d0bbb9fdba88da0b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5b3e07ccfe59cd3c9af5551d61fdc2f1.setIcon(icon_0e4a05351bcef1c0d0bbb9fdba88da0b);
#
#
#         var popup_e0de4e98619aaf6c40e82040a5053edd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_298947ab06930defac2d1693061b773e = $(`&lt;div id=&quot;html_298947ab06930defac2d1693061b773e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;white-space: nowrap;&quot;&gt;주소: 서울특별시 종로구 송월길 130&lt;br&gt;주택 종류: 아파트&lt;br&gt;면적: 39&lt;br&gt;세대수: 188&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_e0de4e98619aaf6c40e82040a5053edd.setContent(html_298947ab06930defac2d1693061b773e);
#
#
#
#         marker_5b3e07ccfe59cd3c9af5551d61fdc2f1.bindPopup(popup_e0de4e98619aaf6c40e82040a5053edd)
#         ;
#
#
#
#
#             var marker_ca7c1e286c7781c71befb40672c1a61b = L.marker(
#                 [37.573843065, 127.015199891],
#                 {}
#             ).addTo(map_244f2bb5e33b9838e372940e5b6e3d45);
#
#
#             var icon_79602cdfc784a7c71c1a45d11c85d617 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca7c1e286c7781c71befb40672c1a61b.setIcon(icon_79602cdfc784a7c71c1a45d11c85d617);
#
#
#         var popup_3d39b97b47e6b2d5d376dd427c7f63d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dde77c279aecb14e8e4a69e49673281d = $(`&lt;div id=&quot;html_dde77c279aecb14e8e4a69e49673281d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;white-space: nowrap;&quot;&gt;주소: 서울특별시 종로구 지봉로 37-29&lt;br&gt;주택 종류: 다세대주택&lt;br&gt;면적: 15&lt;br&gt;세대수: 17&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_3d39b97b47e6b2d5d376dd427c7f63d7.setContent(html_dde77c279aecb14e8e4a69e49673281d);
#
#
#
#         marker_ca7c1e286c7781c71befb40672c1a61b.bindPopup(popup_3d39b97b47e6b2d5d376dd427c7f63d7)
#         ;
#
#
#
#
#             var marker_62936030b79d7679e07dedd03517429a = L.marker(
#                 [37.554299594, 126.965023355],
#                 {}
#             ).addTo(map_244f2bb5e33b9838e372940e5b6e3d45);
#
#
#             var icon_ef85afb628d0e27b4e8bd098d411cc3b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_62936030b79d7679e07dedd03517429a.setIcon(icon_ef85afb628d0e27b4e8bd098d411cc3b);
#
#
#         var popup_df00a71519c343bfa3c8df379ac4fa78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_350eb65d4f39e3fef53eac6b2ff5014f = $(`&lt;div id=&quot;html_350eb65d4f39e3fef53eac6b2ff5014f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;white-space: nowrap;&quot;&gt;주소: 서울특별시 중구 만리재로 175&lt;br&gt;주택 종류: 아파트&lt;br&gt;면적: 39&lt;br&gt;세대수: 36&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_df00a71519c343bfa3c8df379ac4fa78.setContent(html_350eb65d4f39e3fef53eac6b2ff5014f);
#
#
#
#         marker_62936030b79d7679e07dedd03517429a.bindPopup(popup_df00a71519c343bfa3c8df379ac4fa78)
#         ;
#
#
#
#
#             var marker_823410b632c69d862370ef63e6f175bb = L.marke

# %% [markdown]
# ### 비트맵(choropleth)으로 청년 주택 수 출력

# %%
import sqlalchemy

from urllib import parse
with open("./db.config",'r') as f:
    db_data = f.read()
db_data = eval(db_data)
_host = db_data['DB_HOST']
_user = db_data['DB_USER']
_password = db_data['DB_PASSWORD']
_name = db_data['DB_NAME']
_port = 3306
_password = parse.quote_plus(_password)
engine = sqlalchemy.create_engine(f"mysql://{_user}:{_password}@{_host}:{_port}/{_name}")

# %%
# 각 구별로 중심점 찾기
import folium
import requests
import json
geo_str = requests.get("https://t1.daumcdn.net/cfile/tistory/272C224C58B4BD540B").json()

from shapely.geometry import Polygon, MultiPolygon
nametoloc = {}
for feature in geo_str['features']:
    geometry = feature['geometry']
    properties = feature['properties']
    
    if geometry['type'] == 'Polygon':
        polygon = Polygon(geometry['coordinates'][0])
        center = polygon.centroid.coords[0]
    elif geometry['type'] == 'MultiPolygon':
        polygon = MultiPolygon([Polygon(coord[0]) for coord in geometry['coordinates']])
        center = polygon.centroid.coords[0]
    else:
        continue
    
    # 중심점을 지도에 표시
    nametoloc[properties['name']] = (center[1],center[0])

# %%
all_apart_map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="cartodb positron")
pd.read_sql("select * from apart_allRentView",con=engine)['자치구'].sort_values().tolist()


apart_df = pd.read_sql("""SELECT A.adresGu, A.num AS number FROM (SELECT A.adresGu,A.AB + IFNULL(B.AB,0) AS num  FROM (SELECT adresGu, COUNT(*) AS AB 
            FROM allLh GROUP BY adresGu ORDER BY adresGu) A LEFT JOIN (SELECT adresGu, IFNULL(COUNT(*),0) 
            AS AB FROM ansim GROUP BY adresGu ORDER BY adresGu) B ON A.adresGu = B.adresGu) A""", con=engine)
folium.Choropleth(geo_str, 
                  data = apart_df, 
                  columns=['adresGu', 'number'],
                  fill_color= "PuRd",
                  key_on = 'feature.id').add_to(all_apart_map)
for idx, row in apart_df.iterrows():
    adres= row['adresGu']; numb = row['number']
    icon1 = folium.DivIcon(html=f"<div style='font-size: 10pt;font-weight:bold;width:200px'>{adres}<br>({numb}개)</div>")
    folium.Marker(location=nametoloc[row['adresGu']],icon=icon1).add_to(all_apart_map)

# %%
#주택 수 출력
all_apart_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88749b6f5d1106b1aa3080b5b9d42f11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88749b6f5d1106b1aa3080b5b9d42f11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88749b6f5d1106b1aa3080b5b9d42f11 = L.map(
#                 &quot;map_88749b6f5d1106b1aa3080b5b9d42f11&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99adcd77d7a0d2e96f49ea6634443f91 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_99adcd77d7a0d2e96f49ea6634443f91.addTo(map_88749b6f5d1106b1aa3080b5b9d42f11);
#
#
#             var choropleth_6fc852ea87a46a44073e15511208b85d = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_4aea1e6148e31e979d69b169763d9477_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4aea1e6148e31e979d69b169763d9477_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4aea1e6148e31e979d69b169763d9477 = L.geoJson(null, {
#                 onEachFeature: geo_json_4aea1e6148e31e979d69b169763d9477_onEachFeature,
#
#                 style: geo_json_4aea1e6148e31e979d69b169763d9477_styler,
#         });
#
#         function geo_json_4aea1e6148e31e979d69b169763d9477_add (data) {
#             geo_json_4aea1e6148e31e979d69b169763d9477
#                 .addData(data);
#         }
#             geo_json_4aea1e6148e31e979d69b169763d9477_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.4974

# %%
#not apart
notapart_avg_df = pd.read_sql("select * from notapart_allRentView", con=engine)
apart_avg_df = pd.read_sql("select * from notapart_allRentView", con=engine)

# %%
pd.read_sql("select * from allLh",con=engine)['kindHouse'].unique()
# Out:
# array(['오피스텔', '다세대주택', '다가구주택', '알수없음', '연립주택', '아파트', '단독주택'],
#       dtype=object)

# %%
pd.read_sql("(select kindHouse from ansim where kindHouse = '아파트')",con=engine)
# Out:
#    kindRental adresGu      adresWay  scaleTot kindHouse totArea  \
# 0        청년안심     은평구    갈현동 456-25       163       아파트      17
# 1        청년안심     중랑구     상봉동 118-8       299       아파트      18
# 2        청년안심     중랑구      봉우재로 111        83       아파트      17
# 3        청년안심     은평구      서오릉로 165       238       아파트      17
# 4        청년안심     동작구     노량진동 54-1       299       아파트      17
# 5        청년안심     동작구    대방동 403-14       110       아파트      18
# 6        청년안심     송파구      문정동 55-6       438       아파트      16
# 7        청년안심     송파구    잠실동 187-10       217       아파트      17
# 8        청년안심     성동구      천호대로416        170       아파트      14
# 9        청년안심     종로구     숭인동 240-1       139       아파트      20
# 10       청년안심     도봉구       도봉로 445       288       아파트      17
# 11       청년안심     은평구    불광동 323-21       264       아파트      17
# 12       청년안심     마포구      서강로75-4        589       아파트      17
# 13       청년안심     종로구     난계로29길55        238       아파트      16
# 14       청년안심    영등포구    당산동2가 45-5       496       아파트      17
# 15       청년안심    동대문구        망우로 46       582       아파트      15
# 16       청년안심     은평구       대조동 2-9       977       아파트      17
# 17       청년안심    서대문구       수색로6길 8       124       아파트      17
# 18       청년안심     도봉구       삼양로602        253       아파트      20
# 19       청년안심     광진구      천호대로 517       299       아파트      16
# 20       청년안심     송파구      석촌호수로 74       298       아파트      16
# 21       청년안심     광진구      구의강변로 51        98       아파트      15
# 22       청년안심     노원구      동일로 1000       270       아파트      16
# 23       청년안심     중랑구     공릉로2길 8-4       235       아파트      16
# 24       청년안심     강서구     강서로56길 44       252       아파트      15
# 25       청년안심     광진구      구의강변로 53        74       아파트      16
# 26       청년안심    영등포구        도신로 59        99       아파트      16
# 27       청년안심     강서구       화곡로 146        82       아파트      20
# 28       청년안심     용산구     원효로97길 15       751       아파트      15
# 29       청년안심     관악구  남부순환로224길 25       201       아파트      15
# 30       청년안심     강서구       강서로 231       429       아파트      17
# 31       청년안심     강남구      봉은사로 125       297       아파트      14
# 32       청년안심     마포구       토정로131         95       아파트      17
# 33       청년안심     강동구      천호대로989        223       아파트      14
# 34       청년안심     서초구    반포대로27길 13       280       아파트      16
# 35       청년안심     용산구     백범로99길40       1086       아파트      19
# 36       청년안심     동작구     노량진로8길55        272       아파트      15
# 37       청년안심     강서구   공항대로59가길14        285       아파트      15
# 38       청년안심    동대문구     망우로21나길6         99       아파트      14
# 39       청년안심     강서구       강서로145         57       아파트      14
# 40       청년안심     강서구      공항대로543        500       아파트      18
# 41       청년안심     마포구        양화로72        913       아파트      17
# 42       청년안심    서대문구       경기대로22        499       아파트      15
# 43       청년안심     서초구    남부순환로 2567       379       아파트      17
# 44       청년안심     강남구       논현로 423        78       아파트      16
# 45       청년안심     광진구      구의강변로 57        70       아파트      16
# 46       청년안심     강남구     논현동 278-4       283       아파트      14
# 47       청년안심     관악구   남부순환로180길 6       299       아파트      17
# 48       청년안심    영등포구     신길동 173-6       162       아파트      16
#
#     publicmoneyRental  publicdepositMoney  privateMoneyDepositLow  \
# 0              290000            40000000                40000000
# 1              280000            43000000                43000000
# 2              300000            36000000                36000000
# 3              290000            36000000                36000000
# 4              310000            45000000                45000000
# 5              240000            34000000                34000000
# 6              360000            42000000                42000000
# 7              330000            46000000                46000000
# 8              340000            38000000                38000000
# 9              340000            44800000                44800000
# 10             260000            26400000                26400000
# 11             260000            40000000                40000000
# 12              62000            37130000                37130000
# 13             300000            30600000                30600000
# 14             310000            58000000                58000000
# 15             100000            54000000                54000000
# 16              90000            56000000                56000000
# 17             400000             4400000                 4400000
# 18             350000            38250000                38250000
# 19             350000            44000000                44000000
# 20             350000            39000000                39000000
# 21             370000            46000000                46000000
# 22             300000            32000000                32000000
# 23             250000            27790000                27790000
# 24             220000            38000000                38000000
# 25             190000            28240000                28240000
# 26             190000            35000000                35000000
# 27              80000            50000000                50000000
# 28             240000            50340000                50340000
# 29             290000            24000000                24000000
# 30             250000             3680000                 3680000
# 31             380000            41570000                41570000
# 32             470000            17000000                17000000
# 33             270000            11050000                11050000
# 34              80000            24750000                24750000
# 35              80000            22840000                22840000
# 36             100000            33040000                33040000
# 37              60000            18630000                18630000
# 38              70000            19290000                19290000
# 39              50000            14960000                14960000
# 40             240000            29040000                29040000
# 41             370000            61200000                61200000
# 42             290000            36400000                36400000
# 43             290000            68000000                68000000
# 44             410000             4900000                 4900000
# 45             340000            44000000                44000000
# 46             240000            31620000                31620000
# 47             340000            37000000                37000000
# 48             290000            37000000                37000000
#
#     privateMoneyDepositHigh  privateMoneyRentalLow  privateMoneyRentalHigh
# 0                  86000000                 290000                  530000
# 1                 132000000                 280000                  760000
# 2                  76000000                 300000                  600000
# 3                  91000000                 290000                  670000
# 4                 191000000                 310000                 1060000
# 5                 128000000                 240000                  730000
# 6                 116000000                 360000                  860000
# 7                 177000000                 330000                 1030000
# 8                  80000000                 340000                  630000
# 9                 144000000                 340000                  850000
# 10                 78400000                 260000                  690000
# 11                110000000                 260000                  670000
# 12                240950000                  62000                  476000
# 13                 87400000                 300000                  760000
# 14                166000000                 310000                  710000
# 15                222000000                 100000                  510000
# 16                261000000                  90000                  600000
# 17                103000000                 400000                  890000
# 18                 76040000                 350000                  590000
# 19                113000000                 350000                  790000
# 20                 11100000                 350000                  770000
# 21                102600000                 370000                  730000
# 22                 99000000                 300000                  810000
# 23                 76360000                 250000                  510000
# 24                 96000000                 220000                  580000
# 25                105090000                 190000                  590000
# 26                122000000                 190000                  670000
# 27                200000000                  80000                  710000
# 28                184800000                 240000                  930000
# 29                103000000                 290000                  910000
# 30                104000000                 250000                  650000
# 31                147440000                 380000                  950000
# 32                129000000                 470000                  990000
# 33                 79810000                 270000                  710000
# 34                103000000                  80000                  790000
# 35                197070000                  80000                  650000
# 36                114420000                 100000                  720000
# 37                 62000000                  60000                  440000
# 38                 74080000                  70000                  670000
# 39                 60040000                  50000                  450000
# 40                 96800000                 240000                  710000
# 41                137600000                 370000                 1120000
# 42                112800000                 290000                  780000
# 43                159000000                 290000                  810000
# 44                123000000                 410000                  860000
# 45                 89000000                 340000                  710000
# 46                105480000                 240000                  680000
# 47                 98000000                 340000                  850000
# 48                152000000                 290000                  790000

# %% [markdown]
# *matplotlib 한글 폰트 설정*
#
#     1. font 설치: sudo apt-get install fonts-nanum
#     2. 캐시 디렉터리 찾기
#     3. 캐시 제거: rm -r [2번에서 찾은 캐시디렉터리 path]
#     4. Nanum Gothic을 폰트 설정

# %%
import matplotlib

#matplot 캐시디렉토리 찾기
matplotlib.get_cachedir()
# Out:
# '/home/david/.cache/matplotlib'

# %%
# 나눔고딕 폰트 설정
from matplotlib import rc
rc('font',family='NanumGothic')

# %%
#한글 설정 확인
import matplotlib.pyplot as plt

plt.bar(['가나다','라마바'],[1,2])
plt.title('호감지수')
# Out:
# Text(0.5, 1.0, '호감지수')
