# %%
import requests
import folium
import pandas as pd
import sqlalchemy
from urllib import parse
url = "https://www.starbucks.co.kr/store/getStore.do?r=U1GAWL"
payload = {"in_biz_cds": "0","in_scodes": "0","ins_lat": "37.4909","ins_lng": "127.0231","search_text": "","p_sido_cd": "01","p_gugun_cd": "","in_distance": "0","isError": "true","in_biz_cd": "","iend": "1000","searchType": "C","set_date": "","rndCod": "1EMUI1PR4R","all_store": "0","T03": "0","T01": "0","T27": "0","T12": "0","T09": "0","T30": "0","T05": "0","T22": "0","T21": "0","T10": "0","T36": "0","T43": "0","T48": "0","Z9999": "0","P02": "0","P10": "0","P50": "0","P20": "0","P60": "0","P30": "0","P70": "0","P40": "0","P80": "0","whcroad_yn": "0","P90": "0","P01": "0","new_bool": "0",}
df = pd.DataFrame(requests.post(url, data=payload).json()['list'])
pd.set_option('display.max_columns', None)
star_df = df[['addr', 's_name', 'tel', 'fax', 'gugun_name', 'defaultimage', 'lat', 'lot']].copy()
data = star_df.value_counts('gugun_name')

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=15, tiles="cartodb positron")
geo_str = requests.get("https://t1.daumcdn.net/cfile/tistory/272C224C58B4BD540B").json()

# %%
sql = """
SELECT AverageGu.adresGu,
AVG(CASE WHEN AverageAnsim.ren_type = 'private' AND AverageGu.kindRental != '매입임대'
THEN COALESCE((AverageGu.Average + AverageAnsim.Average) / 2, AverageAnsim.Average)
ELSE NULL END) AS '행복주택 & 민간임대',
COALESCE(apart_allRentView.`전세가`, 0) AS '실거래가 평균'
FROM AverageGu
JOIN AverageAnsim ON AverageGu.adresGu = AverageAnsim.adresGu
LEFT JOIN apart_allRentView ON apart_allRentView.`자치구` = AverageAnsim.adresGu
GROUP BY AverageAnsim.adresGu;
"""


sql2 = """
SELECT AverageAnsim.adresGu,
AVG(CASE WHEN AverageAnsim.ren_type = 'public' AND AverageGu.kindRental != '행복주택' THEN (AverageGu.Average + AverageAnsim.Average) / 2 ELSE NULL END)
AS '매입임대 & 공공임대',
notapart_allRentView.`전세가` AS '실거래가 평균'
FROM AverageGu
JOIN AverageAnsim ON AverageGu.adresGu = AverageAnsim.adresGu
JOIN notapart_allRentView ON notapart_allRentView.`자치구` = AverageGu.adresGu
GROUP BY AverageGu.adresGu;
"""

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 31.4 MB/s eta 0:00:0000:010:01
# Collecting pillow>=8
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 35.6 MB/s eta 0:00:0000:0100:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 36.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/bobb/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.7 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 KB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /home/bobb/.local/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/bobb/.local/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 pillow-10.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family=font_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from matplotlib import font_manager, rc
#       2 font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
# ----> 3 font_name = font_manager.FontProperties(fname = font_path).get_name()
#       4 rc('font', family=font_name)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/font_manager.py:669, in FontProperties.get_name(self)
#     665 def get_name(self):
#     666     """
#     667     Return the name of the font that best matches the font properties.
#     668     """
# --> 669     return get_font(findfont(self)).family_name
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/font_manager.py:1554, in get_font(font_filepaths, hinting_factor)
#    1551 if hinting_factor is None:
#    1552     hinting_factor = mpl.rcParams['text.hinting_factor']
# -> 1554 return _get_font(
#    1555     # must be a tuple to be cached
#    1556     paths,
#    1557     hinting_factor,
#    1558     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1559     # also key on the thread ID to prevent segfaults with multi-threading
#    1560     thread_id=threading.get_ident()
#    1561 )
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/font_manager.py:1496, in _get_font(font_filepaths, hinting_factor, _kerning_factor, thread_id)
#    1493 @lru_cache(64)
#    1494 def _get_font(font_filepaths, hinting_factor, *, _kerning_factor, thread_id):
#    1495     first_fontpath, *rest = font_filepaths
# -> 1496     return ft2font.FT2Font(
#    1497         first_fontpath, hinting_factor,
#    1498         _fallback_list=[
#    1499             ft2font.FT2Font(
#    1500                 fpath, hinting_factor,
#    1501                 _kerning_factor=_kerning_factor
#    1502             )
#    1503             for fpath in rest
#    1504         ],
#    1505         _kerning_factor=_kerning_factor
#    1506     )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# %%
from matplotlib import font_manager, rc
font_path = "./font/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[248], line 3
#       1 from matplotlib import font_manager, rc
#       2 font_path = "./font/malgun.ttf"
# ----> 3 font_name = font_manager.FontProperties(fname = font_path).get_name()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/font_manager.py:669, in FontProperties.get_name(self)
#     665 def get_name(self):
#     666     """
#     667     Return the name of the font that best matches the font properties.
#     668     """
# --> 669     return get_font(findfont(self)).family_name
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/font_manager.py:1554, in get_font(font_filepaths, hinting_factor)
#    1551 if hinting_factor is None:
#    1552     hinting_factor = mpl.rcParams['text.hinting_factor']
# -> 1554 return _get_font(
#    1555     # must be a tuple to be cached
#    1556     paths,
#    1557     hinting_factor,
#    1558     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1559     # also key on the thread ID to prevent segfaults with multi-threading
#    1560     thread_id=threading.get_ident()
#    1561 )
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/font_manager.py:1496, in _get_font(font_filepaths, hinting_factor, _kerning_factor, thread_id)
#    1493 @lru_cache(64)
#    1494 def _get_font(font_filepaths, hinting_factor, *, _kerning_factor, thread_id):
#    1495     first_fontpath, *rest = font_filepaths
# -> 1496     return ft2font.FT2Font(
#    1497         first_fontpath, hinting_factor,
#    1498         _fallback_list=[
#    1499             ft2font.FT2Font(
#    1500                 fpath, hinting_factor,
#    1501                 _kerning_factor=_kerning_factor
#    1502             )
#    1503             for fpath in rest
#    1504         ],
#    1505         _kerning_factor=_kerning_factor
#    1506     )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/bobb/workspace/realestate/font/malgun.ttf'

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 경로
font_path = '/usr/share/fonts/nanum/NanumGothic.ttf'

# 폰트 설정
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()

# 시각화 코드
plt.figure(figsize=(10, 6))
plt.bar(vs_mae_not['자치구'], vs_mae_not['매입임대 평균가'], color='blue', alpha=0.5, label='매입임대 평균가')
plt.bar(vs_mae_not['자치구'], vs_mae_not['비아파트 평균가'], color='red', alpha=0.5, label='비아파트 평균가')
plt.xlabel('자치구', fontproperties=font_prop)
plt.ylabel('평균가', fontproperties=font_prop)
plt.title('매입임대와 비아파트 평균가 비교', fontproperties=font_prop)
plt.xticks(rotation=45, fontproperties=font_prop)
plt.legend(prop=font_prop)
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %%
import sqlalchemy
from urllib import parse

user = 'encore1'
password = 'EnCore1!@#'
host='13.125.65.37'
port = 3306
database = 'encore1'
password = parse.quote_plus(password)
engine = sqlalchemy.create_engine(f"mysql://{user}:{password}@{host}:{port}/{database}")

# %%
sql_query = """
    SELECT AverageAnsim.adresGu,
           AVG(CASE WHEN AverageAnsim.ren_type = 'public' AND AverageGu.kindRental != '행복주택' THEN (AverageGu.Average + AverageAnsim.Average) / 2 ELSE NULL END) AS avg_rental,
           AVG(notapart_allRentView.`전세가`) AS avg_price
    FROM AverageGu
    JOIN AverageAnsim ON AverageGu.adresGu = AverageAnsim.adresGu
    JOIN notapart_allRentView ON notapart_allRentView.`자치구` = AverageGu.adresGu
    GROUP BY AverageGu.adresGu
"""

# %%
import pandas as pd
apart_allRentView = pd.read_sql_query("select * from apart_allRentView", con=engine)
notapart_allRentView = pd.read_sql_query("select * from notapart_allRentView", con=engine)
ansimView = pd.read_sql_query("select * from ansimView", con=engine)
allLhView = pd.read_sql_query("select * from allLhView", con=engine)
# result = pd.read_sql_query(sql_query, con=engine)

# %%
maeavg=allLhView[allLhView['kindRental']=='매입임대'].groupby(['adresGu'],as_index=False)[['alldeposit']].mean()
hangavg=allLhView[allLhView['kindRental']=='행복주택'].groupby(['adresGu'],as_index=False)[['alldeposit']].mean()
apart_allRentView.rename(columns={'자치구':'adresGu', '전세가':'alldeposit'},inplace=True)
notapart_allRentView.rename(columns={'자치구':'adresGu', '전세가':'alldeposit'},inplace=True)

# %%
maeavg.alldeposit=maeavg.alldeposit.astype(int)
hangavg.alldeposit=hangavg.alldeposit.astype(int)
apart_allRentView.alldeposit=apart_allRentView.alldeposit.astype(int)
notapart_allRentView.alldeposit=notapart_allRentView.alldeposit.astype(int)

# %%
# pd.merge([maeavg,notapart_allRentView])
vs_mae_not=pd.merge(maeavg,notapart_allRentView, on ='adresGu', how ='left')
vs_mae_not.rename(columns={'adresGu':'자치구','alldeposit_x':'매입임대 평균가', 'alldeposit_y':'비아파트 평균가'},inplace=True)
vs_mae_not
# Out:
#      자치구  매입임대 평균가   비아파트 평균가
# 0    강남구  74748521  206069119
# 1    강동구  71043611  162090851
# 2    강북구  48108678  129596375
# 3    강서구  34125684  165078086
# 4    관악구  34191496  140092267
# 5    광진구  68391452  157167182
# 6    구로구  51814233  137573073
# 7    금천구  55447244  148131036
# 8    노원구  50348810  113658366
# 9    도봉구  39763060  131251917
# 10  동대문구  62897902  151649057
# 11   동작구  63411727  141077806
# 12   마포구  66711697  167727263
# 13  서대문구  48894970  153069472
# 14   서초구  98657419  195418329
# 15   성동구  60767454  157550988
# 16   성북구  53327861  139856463
# 17   송파구  74303728  189187484
# 18   양천구  47994917  161062382
# 19  영등포구  79008485  176792017
# 20   용산구  73607679  168101593
# 21   은평구  46627054  145578611
# 22   종로구  64546626  151064555
# 23    중구  86776825  173411049
# 24   중랑구  58128947  148309596
